# %%
import pandas as pd

season = 'NBA 2020-21'
download_file = f'../data/downloaded/{season}.xlsx'

data_xls_A = pd.read_excel(download_file, index_col=None)

data_xls['season'] = season

data_xls
# Out:
#       Date  Rot VH          Team  1st  2nd  3rd  4th  Final   Open  Close  \
# 0     1222  501  V   GoldenState   25   20   26   28     99    228  234.5
# 1     1222  502  H      Brooklyn   40   23   36   26    125    5.5    7.5
# 2     1222  503  V    LAClippers   39   17   33   27    116    223    219
# 3     1222  504  H      LALakers   19   35   24   31    109    2.5      2
# 4     1223  551  V     Charlotte   23   21   36   34    114    215      3
# ...    ...  ... ..           ...  ...  ...  ...  ...    ...    ...    ...
# 2231   530  508  H        Dallas   22   23   15   21     81  222.5  219.5
# 2232   531  511  V  Philadelphia   31   30   19   34    114    7.5    8.5
# 2233   531  512  H    Washington   28   32   32   30    122  230.5    231
# 2234   531  513  V          Utah   34   25   41   20    120    5.5    5.5
# 2235   531  514  H       Memphis   31   23   33   26    113    224  224.5
#
#        ML     2H       season
# 0     265      1  NBA 2020-21
# ...
